# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('/content/listings_Excel_PBI_FULL.xlsx') # considerando apenas as top 5 cidades em quantidade de imóveis (Copacabana, Barra da Tijuca, Ipanema, Jacarepaguá e
# Recreio dos Bandeirantes).
df.head()
# Out:
#   neighbourhood_cleansed  latitude  longitude  accommodates  bathrooms  \
# 0             Copacabana  -2296599    -431794             5        1.0
# 1                Ipanema  -2298586   -4319411             2        1.0
# 2             Copacabana  -2296582   -4317786             2        1.0
# 3                Ipanema  -2298405   -4320189             2        1.0
# 4                Ipanema  -2298335   -4320306             5        3.0
#
#    bedrooms  beds  price  minimum_nights  maximum_nights  ...  \
# 0       2.0   2.0    350               5              28  ...
# 1       1.0   1.0    100              30             180  ...
# 2       1.0   1.0    266               3              89  ...
# 3       1.0   1.0    624               3              90  ...
# 4       3.0   3.0   1899               5             300  ...
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                      463.0                  483.0
# 1                      482.0                  494.0
# ...

# %%
df.corr()
# Out:
# <ipython-input-4-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                               latitude  longitude  \
# latitude                                      1.000000   0.501504
# longitude                                     0.501504   1.000000
# accommodates                                  0.007586   0.003905
# bathrooms                                     0.012341   0.017241
# bedrooms                                      0.008644   0.012574
# beds                                          0.028321   0.020352
# price                                         0.009795   0.005576
# minimum_nights                                0.026778   0.020529
# maximum_nights                                0.067271   0.054347
# ...

# %%
corr_export = df.corr()
corr_export.to_excel('corr_export_full.xlsx')
# Out:
# <ipython-input-5-b8246cc021ed>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_export = df.corr()
